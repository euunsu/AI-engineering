# %% [markdown]
# # 깃허브 명령어

# %%
# !git clone https://euunsu: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@github.com/euunsu/AI-engineering.git
# Out:
# Cloning into 'AI-engineering'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# !git config --global user.email 'eunsu416@gmail.com'
# !git config --global user.name 'euunsu'

# %%
# !git add AI_1.ipynb

# %%
# !git commit -m "깃허브 & 코랩 연동"
# Out:
# [main 0eb3eda] 깃허브 & 코랩 연동
#  1 file changed, 1 insertion(+)
#  create mode 100644 AI_1.ipynb

# %%
# !git push
# Out:
# remote: Permission to euunsu/AI-engineering.git denied to euunsu.
# fatal: unable to access 'https://github.com/euunsu/AI-engineering.git/': The requested URL returned error: 403

# %% [markdown]
# # 드라이브 마운트 및 경로 설정

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/Github
# Out:
# /content/drive/MyDrive/Github

# %%
pwd

# %%
cd AI-engineering
# Out:
# /content/drive/MyDrive/Github/AI-engineering
